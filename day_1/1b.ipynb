# %%
import os 
from dotenv import load_dotenv

#load variables from the .env file
load_dotenv()

# Get the key from the environment
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

if GOOGLE_API_KEY:
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("Gemini API key set successfully.")
else: 
    print("GOOGLE_API_KEY not found in environment variables.")
# Out:
# Gemini API key set successfully.

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# %% [markdown]
# # Multi-Agent System

# %% [markdown]
# 2.1 Example: Research & Summarization System¶
# Let's build a system with two specialized agents:
#
# Research Agent - Searches for information using Google Search
#
# Summarizer Agent - Creates concise summaries from research findings

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

print("research_agent created.")
# Out:
# research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("summarizer_agent created.")
# Out:
# summarizer_agent created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
    1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
    2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
    3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

print("root_agent created.")
# Out:
# root_agent created.

# %% [markdown]
# Here we're using AgentTool to wrap the sub-agents to make them callable tools for the root agent. We'll explore AgentTool in-detail on Day 2.
#
# Let's run the agent and ask it about a topic:

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "What are the latest advancements in quantum computing and what do they mean for AI?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > Quantum computing is rapidly advancing and poised to revolutionize AI by offering unprecedented computational power and new algorithmic approaches. This synergy, often termed "Quantum AI," promises to overcome classical computing limitations and unlock new levels of AI capabilities.
#
# Key advancements include:
# *   **Enhanced AI Model Training and Performance:** Quantum computers can process vast datasets exponentially faster, significantly reducing training time and computational resources for complex AI models, leading to improved accuracy and faster decision-making.
# *   **Solving Intractable Problems:** Quantum computing's ability to explore numerous possibilities concurrently allows AI to tackle complex optimization and simulation problems in areas like drug discovery, materials science, financial modeling, and logistics, which are currently beyond the reach of classical systems.
# *   **New Algorithmic Possibilities:** The principles of quantum mechanics enable the development of novel quantum machine learning (QML) algorithms that can offer significant advantages in speed, scalability, and accuracy for pattern recognition, natural language processing, and data classification.
# *   **AI for Quantum Systems:** AI is also being used to improve quantum computing itself by predicting and correcting errors, making quantum systems more reliable and efficient, and assisting in the design of quantum chip architectures.
# *   **Hybrid Approaches:** In the near term, hybrid quantum-classical approaches are expected to dominate, combining the strengths of both classical and quantum computing for practical applications.
#
# While challenges remain, including hardware limitations and a shortage of skilled professionals, the rapid advancements suggest that Quantum AI is moving beyond theoretical concepts into tangible, real-world applications, with significant growth projected in the coming years.

# %% [markdown]
# # Section 3: Sequential Workflows : Assembly Line

# %% [markdown]
# The Problem: Unpredictable Order
#
# The previous multi-agent system worked, but it relied on a detailed instruction prompt to force the LLM to run steps in order. This can be unreliable. A complex LLM might decide to skip a step, run them in the wrong order, or get "stuck," making the process unpredictable.
#
# The Solution: A Fixed Pipeline
#
# When you need tasks to happen in a guaranteed, specific order, you can use a SequentialAgent. This agent acts like an assembly line, running each sub-agent in the exact order you list them. The output of one agent automatically becomes the input for the next, creating a predictable and reliable workflow.
#
# Use Sequential when: Order matters, you need a linear pipeline, or each step builds on the previous one.

# %%
outline_agent = Agent(
    name ="OutlineAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key.
)

print("outline_agent created.")
# Out:
# outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),

    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",  # The result of this agent will be stored with this key.
)

print("writer_agent created.")
# Out:
# writer_agent created.

# %%
editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

print("editor_agent created.")
# Out:
# editor_agent created.

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent]
)
print("Sequential Agent created.")
# Out:
# Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a blog post about the benefits of multi-agent systems for software developers"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > Here's a blog outline about the benefits of multi-agent systems for software developers:
#
# ### **Headline: Unleash Your Development Superpowers: How Multi-Agent Systems Will Revolutionize Your Code**
#
# **Introduction Hook:**
# Ever feel like your software projects are a tangled mess of dependencies and complex logic? What if there was a way to break down those massive challenges into smaller, smarter, and more collaborative pieces? Enter Multi-Agent Systems (MAS) – a paradigm shift that's not just for AI research anymore, but a powerful toolkit for *you*, the software developer. Get ready to discover how MAS can make your development process more efficient, robust, and intelligent.
#
# **Main Sections:**
#
# **1. The Power of Decomposition: Taming Complexity with Agentic Division**
#     *   **Break It Down:** MAS allows you to decompose large, monolithic applications into smaller, independent, and specialized "agents." Each agent can focus on a specific task or domain, making code easier to understand, develop, and maintain.
#     *   **Modular Marvels:** This modularity significantly reduces cognitive load. Developers can concentrate on individual agent functionalities without getting bogged down by the entire system's intricacies.
#     *   **Specialized Expertise:** Assign specific roles and responsibilities to agents, mirroring real-world specialization and leading to more focused and efficient development efforts for each component.
#
# **2. Enhanced Robustness and Resilience: Building Software That Bounces Back**
#     *   **Fault Isolation:** If one agent fails, the entire system doesn't have to crumble. MAS architecture inherently isolates faults, allowing other agents to continue functioning or gracefully handle the failure.
#     *   **Redundancy and Graceful Degradation:** Implement redundant agents for critical functions. If a primary agent goes offline, a backup can seamlessly take over, ensuring continuous operation or a controlled degradation of service.
#     *   **Self-Healing Capabilities:** Agents can be designed to monitor each other, detect anomalies, and even attempt to restart or reconfigure failed peers, leading to more autonomous and resilient systems.
#
# **3. Dynamic Collaboration and Emergent Intelligence: Smarter Software Through Interaction**
#     *   **Agent Communication:** MAS facilitates sophisticated communication protocols between agents, allowing them to share information, coordinate actions, and negotiate solutions to complex problems.
#     *   **Distributed Problem Solving:** Tackle problems that are too large or complex for a single entity by distributing the workload and intelligence across multiple collaborating agents.
#     *   **Emergent Behavior:** Observe how simple agent interactions can lead to complex, adaptive, and intelligent system-level behavior that wasn't explicitly programmed into any single agent. This is where the "magic" happens!
#
# **4. Agility and Adaptability: Evolving Your Software with Ease**
#     *   **Adding/Removing Agents:** New functionalities can be introduced by adding new agents, and outdated components can be retired by removing them, all without a complete system overhaul.
#     *   **Dynamic Reconfiguration:** Agents can dynamically change their behavior, communication strategies, or even form new coalitions in response to changing environmental conditions or project requirements.
#     *   **Scalability on Demand:** Scale your system by simply adding more agents of a particular type to handle increased load or demand for specific functionalities.
#
# **Concluding Thought:**
# Multi-Agent Systems offer a powerful new lens through which software developers can design, build, and evolve complex systems. By embracing decomposition, fostering collaboration, and leveraging emergent intelligence, you can unlock new levels of robustness, efficiency, and adaptability in your software projects. It's time to think beyond single, monolithic programs and step into the future of intelligent, distributed development.
# WriterAgent > ### Unleash Your Development Superpowers: How Multi-Agent Systems Will Revolutionize Your Code
#
# Ever feel like your software projects are a tangled mess of dependencies and complex logic? What if there was a way to break down those massive challenges into smaller, smarter, and more collaborative pieces? Enter Multi-Agent Systems (MAS) – a paradigm shift that's not just for AI research anymore, but a powerful toolkit for *you*, the software developer. Get ready to discover how MAS can make your development process more efficient, robust, and intelligent.
#
# One of the most significant benefits of MAS is **The Power of Decomposition**. Imagine breaking down a monolithic application into independent, specialized "agents." Each agent handles a specific task, making your codebase easier to understand, develop, and maintain. This modularity drastically reduces cognitive load, allowing you to focus on individual agent functionalities without getting lost in the system's overall complexity.
#
# Beyond simplifying development, MAS offers **Enhanced Robustness and Resilience**. If one agent fails, the entire system doesn't have to crumble. MAS architecture inherently isolates faults. You can even implement redundant agents for critical functions, ensuring continuous operation or graceful degradation if a primary agent goes offline. This leads to software that truly bounces back.
#
# Furthermore, MAS fosters **Dynamic Collaboration and Emergent Intelligence**. Agents communicate, coordinate, and negotiate to solve problems collaboratively. This distributed problem-solving approach tackles challenges too large for any single component. The true magic? Witnessing how simple agent interactions can lead to complex, adaptive, and intelligent system-level behavior that wasn't explicitly programmed.
#
# Finally, MAS provides unparalleled **Agility and Adaptability**. Adding new features is as simple as adding a new agent, and retiring old ones is straightforward. Your system can dynamically reconfigure itself and scale on demand by simply adding more agents.
#
# Multi-Agent Systems offer a powerful new way to design and build complex software. By embracing decomposition, collaboration, and emergent intelligence, you can unlock new levels of robustness, efficiency, and adaptability. It's time to think beyond monolithic programs and step into the future of intelligent, distributed development.
# EditorAgent > ### Unleash Your Development Superpowers: How Multi-Agent Systems Will Revolutionize Your Code
#
# Do your software projects often feel like an overwhelming tangle of dependencies and intricate logic? Imagine a scenario where you could break down these monumental challenges into smaller, smarter, and more collaborative units. Multi-Agent Systems (MAS) offer precisely this paradigm shift, moving beyond theoretical AI research to become a potent toolkit for *you*, the software developer. Prepare to discover how MAS can elevate your development process, making it more efficient, robust, and intelligent.
#
# One of the most compelling advantages of MAS is **The Power of Decomposition**. Picture transforming a massive monolithic application into a collection of independent, specialized "agents." Each agent can be dedicated to a specific task, drastically simplifying your codebase, making it easier to understand, develop, and maintain. This inherent modularity significantly reduces cognitive load, allowing you to concentrate on individual agent functionalities without getting lost in the labyrinth of the entire system's complexity.
#
# Beyond simplifying development, MAS delivers **Enhanced Robustness and Resilience**. A critical advantage here is fault isolation: if one agent encounters an issue, the entire system doesn't need to collapse. MAS architecture naturally contains failures, preventing a single point of failure from bringing everything down. You can even implement redundant agents for mission-critical functions, guaranteeing continuous operation or enabling graceful degradation if a primary agent becomes unavailable. This architectural approach results in software that is truly resilient and capable of bouncing back from adversity.
#
# Furthermore, MAS fosters **Dynamic Collaboration and Emergent Intelligence**. Agents are designed to communicate, coordinate, and negotiate with each other to solve problems collectively. This distributed problem-solving approach is ideal for tackling challenges that are simply too large or complex for any single component to handle. The true marvel lies in witnessing how simple, localized agent interactions can give rise to sophisticated, adaptive, and intelligent system-level behaviors that were not explicitly programmed into any individual agent.
#
# Finally, MAS provides unparalleled **Agility and Adaptability**. Incorporating new features becomes as straightforward as introducing a new agent, and retiring outdated ones is equally simple. Your system gains the ability to dynamically reconfigure itself and scale on demand simply by adding or removing agents as needed.
#
# Multi-Agent Systems present a powerful new methodology for designing and building sophisticated software. By embracing decomposition, encouraging collaboration, and harnessing emergent intelligence, you can unlock unprecedented levels of robustness, efficiency, and adaptability in your projects. It's time to look beyond traditional monolithic programs and embrace the future of intelligent, distributed development.

# %% [markdown]
# # Section 4: Parallel Workflows - Independent Researchers
#
# ## The Problem: The Bottleneck
#
# The previous sequential agent is great, but it's an assembly line. Each step must wait for the previous one to finish. What if you have several tasks that are not dependent on each other? For example, researching three different topics. Running them in sequence would be slow and inefficient, creating a bottleneck where each task waits unnecessarily.
#
# ## The Solution: Concurrent Execution
#
# When you have independent tasks, you can run them all at the same time using a ParallelAgent. This agent executes all of its sub-agents concurrently, dramatically speeding up the workflow. Once all parallel tasks are complete, you can then pass their combined results to a final 'aggregator' step.

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
    the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research"
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
    their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research"
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
    their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)
# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchPipeline",
    sub_agents=[parallel_research_team, aggregator_agent]
)

print("✅ Parallel and Sequential Agents created.")
# Out:
# ✅ Parallel and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Run the daily executive briefing on Tech, Health, and Finance")
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# HealthResearcher > Here's a brief executive briefing on recent breakthroughs in Tech, Health, and Finance:
#
# **Health:** Gene editing via CRISPR is rapidly advancing, with practical applications in treating genetic diseases like sickle cell anemia expected within the next decade. Non-hormonal menopause treatments and needle-free allergy relief are now available, offering new options for women and children. Brain-computer interfaces are also showing promise for restoring movement in paralyzed individuals, with ongoing trials.
#
# **Technology:** Agentic AI, capable of handling end-to-end workflows, is evolving from assistance to autonomy, projected for significant market growth by 2026. Quantum computing is nearing practical applications in logistics, finance, and pharmaceuticals, with potential commercialization by 2026. Extended reality (XR) technologies are transforming training and remote collaboration, with significant revenue growth anticipated through 2030.
#
# **Finance:** Embedded finance is becoming a backbone of digital commerce, with projections indicating substantial market growth by 2026. Decentralized finance (DeFi) is maturing with enhanced security and scalability, attracting users from traditional platforms. AI-powered personalization is revolutionizing financial services, with the market expected to double by 2029.
# FinanceResearcher > **Tech:**
# The AI boom continues to reshape industries, with significant investments in AI chip development and startups. Market implications include intense competition and potential shifts in market dominance, particularly between global tech giants. The future outlook suggests AI will drive further innovation and integration across various sectors.
#
# **Health:**
# Focus remains on innovative treatments, such as new ALS drugs and oral GLP-1 medications for obesity. Market implications involve increased healthcare costs and a push for equitable access to these advanced therapies. The future will likely see further breakthroughs in personalized medicine and drug development.
#
# **Finance:**
# The European economy faces pressure from slowing growth, geopolitical risks, and an accelerating tech race, particularly in AI. Market implications include cautious financial markets and increased investment in strategic industries. The outlook suggests a complex interplay of economic, technological, and geopolitical factors influencing global financial markets.
# TechResearcher > **Key AI/ML Trends in 2025-2026:**
#
# **1. Generative AI Expansion:** This trend focuses on AI models that create new content like text, images, video, and code. Companies like **OpenAI** (ChatGPT), **Google** (Gemini, Imagen), and **Microsoft** are heavily involved. Its impact is widespread, from revolutionizing content creation and marketing to aiding in software development and personalized user experiences.
#
# **2. Agentic AI and Autonomous Workflows:** AI agents are evolving to perform complex tasks with minimal human intervention, automating workflows across various sectors. Key players include those developing advanced AI platforms, with implications for customer support, legal services, and finance.
#
# **3. Multimodal AI:** This development enables AI systems to understand and process various data types (text, images, audio, video) simultaneously. This leads to more human-like interactions and enhanced decision-making. Major tech companies like **Google** and **Microsoft** are driving this advancement, with significant potential in healthcare for diagnostics and in creating richer user experiences.
#
# **Companies Involved:** Prominent companies leading these trends include **Google**, **Microsoft**, **NVIDIA**, **OpenAI**, **Amazon**, and **Meta**.
#
# **Potential Impact:** These advancements promise increased productivity, cost reductions through automation, enhanced customer experiences, and new business models. However, challenges related to AI ethics, security, and workforce adaptation remain critical considerations.
# AggregatorAgent > **Executive Briefing: Tech, Health, and Finance - Convergence and Advancement**
#
# Artificial Intelligence (AI) is the unifying theme across technology, health, and finance, driving unprecedented innovation and market shifts. In **Technology**, generative AI, agentic AI enabling autonomous workflows, and multimodal AI are rapidly expanding, with major players like Google, Microsoft, and OpenAI spearheading advancements. These trends promise significant productivity gains and new business models but necessitate careful consideration of ethical implications and workforce adaptation.
#
# This AI revolution is profoundly impacting **Health**, accelerating gene editing with CRISPR for genetic diseases, and enhancing diagnostic capabilities through multimodal AI. Breakthroughs also include non-hormonal menopause treatments, needle-free allergy relief, and promising brain-computer interfaces for paralysis. While these innovations offer transformative patient care, they also raise concerns about healthcare costs and equitable access.
#
# In **Finance**, AI-powered personalization is revolutionizing services, complementing the growth of embedded finance and maturing DeFi platforms. However, the sector faces economic pressures, geopolitical risks, and intense competition fueled by the AI race, particularly in Europe.
#
# **Key Takeaways:**
# *   AI is the primary driver of innovation and disruption across all three sectors.
# *   Convergence is evident, with AI enhancing healthcare diagnostics and financial services.
# *   Significant advancements promise increased efficiency and novel solutions, but ethical, cost, and access challenges must be addressed.

# %% [markdown]
# # Section 5: Loop Workflows - The Refinement Cycle
#
# ## The Problem: One-Shot Quality
#
# All the workflows we've seen so far run from start to finish. The SequentialAgent and ParallelAgent produce their final output and then stop. This 'one-shot' approach isn't good for tasks that require refinement and quality control. What if the first draft of our story is bad? We have no way to review it and ask for a rewrite.
#
# ## The Solution: Iterative Refinement
#
# When a task needs to be improved through cycles of feedback and revision, you can use a LoopAgent. A LoopAgent runs a set of sub-agents repeatedly until a specific condition is met or a maximum number of iterations is reached. This creates a refinement cycle, allowing the agent system to improve its own work over and over.

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story",  # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")
# Out:
# ✅ initial_writer_agent created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",  # Stores the feedback in the state.
)

print("✅ critic_agent created.")
# Out:
# ✅ critic_agent created.

# %% [markdown]
# Now, we need a way for the loop to actually stop based on the critic's feedback. The LoopAgent itself doesn't automatically know that "APPROVED" means "stop."
#
# We need an agent to give it an explicit signal to terminate the loop.
#
# We do this in two parts:
#
# A simple Python function that the LoopAgent understands as an "exit" signal.
# An agent that can call that function when the right condition is met.
# First, you'll define the exit_loop function:

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}

print("✅ exit_loop function created.")
# Out:
# ✅ exit_loop function created.

# %%
# this agent is the "brain" of the loop. It reads the {critique} from the CriticAgent and decides whether to (1) call the exit_loop tool or (2) rewrite the story.
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
        output_key="current_story",  # It overwrites the story with the new, refined version.
        tools=[FunctionTool(exit_loop)],  # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")
# Out:
# ✅ refiner_agent created.

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2  # Safety limit to prevent infinite loops.
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop and Sequential Agents created.")
# Out:
# ✅ Loop and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > The salt spray clung to Elias’s beard as he polished the great lamp. For fifty years, the rhythmic sweep of light had been his only companion, the ceaseless roar of the ocean his lullaby. Tonight, however, the familiar comfort was broken. Tucked beneath a loose floorboard in the storeroom, a rolled parchment pulsed with an ethereal blue light. Unfurling it, Elias found not nautical charts, but an intricate map drawn in luminous ink. Islands he’d never seen, marked with symbols that defied understanding, shimmered before him. A single, bold X glowed at the heart of a forgotten sea. Elias, his heart thrumming with an ancient adventure, traced the glowing lines with a trembling finger. The lighthouse, his world, suddenly felt impossibly small.
# CriticAgent > The story is a strong start, setting a clear mood and introducing an intriguing mystery. Here are a few suggestions to enhance it further:
#
# 1.  **Deepen Elias's characterization:** While we understand his routine and his isolation, giving Elias a brief internal thought or memory about his past, or what he *longs* for beyond his lighthouse duties, would make his sudden spark of adventure more resonant. Is he lonely? Does he regret a life not lived? Even a subtle hint would add depth.
# 2.  **Elaborate on the map's mystery:** The description of the "symbols that defied understanding" is good, but you could tease out a bit more. Are they star charts? Ancient runes? Perhaps a single, almost recognizable symbol that hints at a connection to Elias's past or the lighthouse itself. This would add to the immediate intrigue.
# 3.  **Strengthen the ending's impact:** The line "The lighthouse, his world, suddenly felt impossibly small" is effective. To build on this, consider adding a single, decisive action Elias takes. Does he carefully roll the map back up, his resolve firm? Does he look out at the dark sea with a new determination in his eyes? This final beat would leave a stronger impression of the shift Elias has undergone.
# RefinerAgent > The salt spray clung to Elias’s beard as he polished the great lamp, the rhythmic sweep of its light his only companion for fifty years, the ceaseless roar of the ocean his lullaby. He’d long since made peace with the solitude, though sometimes, on nights like these, a ghost of a longing would stir – a faint memory of a shore he’d left behind, a life of bustling ports and shared laughter he’d traded for this stoic, lonely vigil. Tonight, however, the familiar comfort was broken. Tucked beneath a loose floorboard in the storeroom, a rolled parchment pulsed with an ethereal blue light.
#
# Unfurling it, Elias found not nautical charts, but an intricate map drawn in luminous ink. Islands he’d never seen, marked with symbols that seemed to writhe like ancient runes, shimmered before him. One symbol, a coiled serpent biting its own tail, Elias almost recognized – a sigil his grandmother, a woman whispered to have sea-witch blood, used to wear. A single, bold X glowed at the heart of a forgotten sea. Elias, his heart thrumming with an ancient adventure that echoed the forgotten longings of his youth, traced the glowing lines with a trembling finger. The lighthouse, his world, suddenly felt impossibly small. He carefully rolled the parchment, the glowing X imprinted on his mind, and walked to the tower’s edge, his gaze fixed on the dark, churning sea, a new, unshakeable resolve hardening his features.
# CriticAgent > APPROVED
